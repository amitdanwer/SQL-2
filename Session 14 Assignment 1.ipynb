# %%
#1. Create an sqlalchemy engine using a sample from the data set
#https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data

import numpy as np
import pandas as pd
from sqlalchemy import create_engine
from numpy import genfromtxt
import sqlite3

# %%
from pandasql import sqldf
engine = create_engine('sqlite:///Northwind.sqlite')

# %%
engine.execute('CREATE TABLE "adult_data"(' 
    'age INTEGER,' 
    'workclass TEXT,'
    'fnlwgt INTEGER,'
    'education TEXT,' 
    'education_num INTEGER, '
    'marital_status TEXT, '
    'occupation TEXT, '
    'relationship TEXT,'
    'race TEXT,'
    'sex TEXT,'
    'capital_gain FLOAT,'
    'capital_loss FLOAT,'
    'hours_per_week INTEGER,'
    'native_country TEXT,'
    'salary FLOAT);')

# %%
#result = engine.execute("select * from adult_data LIMIT 10")
#print(result.fetchall())
df = pd.read_sql_query("SELECT * from adult_data", engine)
df
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 0       31            Private   45781        Masters             14
# 1       39          State-gov   77516      Bachelors             13
# 2       50   Self-emp-not-inc   83311      Bachelors             13
# 3       38            Private  215646        HS-grad              9
# 4       53            Private  234721           11th              7
# 5       28            Private  338409      Bachelors             13
# 6       37            Private  284582        Masters             14
# 7       49            Private  160187            9th              5
# 8       52   Self-emp-not-inc  209642        HS-grad              9
# 9       31            Private   45781        Masters             14
# 10      42            Private  159449      Bachelors             13
# 11      37            Private  280464   Some-college             10
# 12      30          State-gov  141297      Bachelors             13
# ...

# %%
file = open('adult.data', mode='r')

# %%
file.close()

# %%
for line in file:
    line_split = line.split(',')
    q="insert into adult_data values("+line_split[0]+","+"'"+line_split[1]+"'"+","+line_split[2]+","+"'"+line_split[3]+"'"+","+line_split[4]+","+"'"+line_split[5]+"'"+","+"'"+line_split[6]+"'"+","+"'"+line_split[7]+"'"+","+"'"+line_split[8]+"'"+","+"'"+line_split[9]+"'"+","+line_split[10]+","+line_split[11]+","+line_split[12]+","+"'"+line_split[13]+"'"+","+"'"+line_split[14]+"'"")"
    engine.execute(q)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-b1595317fcb9> in <module>()
#       1 for line in file:
#       2     line_split = line.split(',')
# ----> 3     q="insert into adult_data values("+line_split[0]+","+"'"+line_split[1]+"'"+","+line_split[2]+","+"'"+line_split[3]+"'"+","+line_split[4]+","+"'"+line_split[5]+"'"+","+"'"+line_split[6]+"'"+","+"'"+line_split[7]+"'"+","+"'"+line_split[8]+"'"+","+"'"+line_split[9]+"'"+","+line_split[10]+","+line_split[11]+","+line_split[12]+","+"'"+line_split[13]+"'"+","+"'"+line_split[14]+"'"")"
#       4     engine.execute(q)
#       5
#
# IndexError: list index out of range
